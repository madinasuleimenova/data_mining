# %%
import numpy as np
import pandas as pd
import pickle

# %%
data = np.genfromtxt('C:\\Users\\sulej\\OneDrive\\Рабочий стол\\7 semester\\Data Mining\\Apple_price_to_clean.csv', delimiter=',')

# %%
pd.DataFrame(data)
# Out:
#        0           1           2           3           4           5  \
# 0    NaN         NaN         NaN         NaN         NaN         NaN
# 1    NaN   27.777500         NaN         NaN   25.934999         NaN
# 2    NaN   26.772499   27.472500   26.262501   27.422501   25.039267
# 3    NaN   28.057501   28.309999   27.504999   28.230000   25.776581
# 4    NaN   28.042500   28.327499   27.885000   28.322500   25.861042
# ...   ..         ...         ...         ...         ...         ...
# 1770 NaN  173.750000  174.899994  173.119995  174.149994  174.149994
# 1771 NaN  173.029999  173.740005  171.309998  171.520004  171.520004
# 1772 NaN  169.690002  169.860001  167.139999  167.570007  167.570007
# 1773 NaN  167.080002  168.710007  166.649994  167.229996  167.229996
# 1774 NaN  167.320007  168.110001  166.250000  167.529999  167.529999
#
#                 6
# 0             NaN
# 1     414406400.0
# 2     387098400.0
# 3     338464400.0
# 4             NaN
# ...           ...
# ...

# %%
# I want to check do i have data with string datatype
data = np.genfromtxt('C:\\Users\\sulej\\OneDrive\\Рабочий стол\\7 semester\\Data Mining\\Apple_price_to_clean.csv', delimiter=',', dtype=None)
# Out:
# C:\Users\sulej\AppData\Local\Temp\ipykernel_19648\2874998450.py:2: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#   data = np.genfromtxt('C:\\Users\\sulej\\OneDrive\\Рабочий стол\\7 semester\\Data Mining\\Apple_price_to_clean.csv', delimiter=',', dtype=None)

# %%
# I had an error so, I google it 
# In newer versions of numpy we need to use encoding parameter, чтобы избежать проблем с кодировкой, особенно для не-ASCII символов, таких как кириллица.
data = np.genfromtxt('C:\\Users\\sulej\\OneDrive\\Рабочий стол\\7 semester\\Data Mining\\Apple_price_to_clean.csv',
                    delimiter=',',
                    dtype=None,
                    encoding='utf-8')

# %%
#head() shows first 5 outputs
pd.DataFrame(data).head()
# Out:
#             0          1          2          3          4          5  \
# 0        Date       Open       High        Low      Close  Adj Close
# 1  2015-08-25  27.777500          -             25.934999      ERROR
# 2  2015-08-26  26.772499  27.472500  26.262501  27.422501  25.039267
# 3  2015-08-27  28.057501  28.309999  27.504999  28.230000  25.776581
# 4  2015-08-28  28.042500  28.327499  27.885000  28.322500  25.861042
#
#            6
# 0     Volume
# 1  414406400
# 2  387098400
# 3  338464400
# 4      ERROR

# %%
# As in Lecture example I also have problem that Column titles are Rows, so 
data = np.genfromtxt('C:\\Users\\sulej\\OneDrive\\Рабочий стол\\7 semester\\Data Mining\\Apple_price_to_clean.csv',
                    delimiter=',',
                    dtype=None,
                    encoding='utf-8',
                    names = True)

# %%
pd.DataFrame(data).head()
# Out:
#          Date       Open       High        Low      Close  Adj_Close  \
# 0  2015-08-25  27.777500          -        NaN  25.934999      ERROR
# 1  2015-08-26  26.772499  27.472500  26.262501  27.422501  25.039267
# 2  2015-08-27  28.057501  28.309999  27.504999  28.230000  25.776581
# 3  2015-08-28  28.042500  28.327499  27.885000  28.322500  25.861042
# 4  2015-08-31  28.007500  28.632500  28.000000  28.190001  25.740063
#
#       Volume
# 0  414406400
# 1  387098400
# 2  338464400
# 3      ERROR
# 4  224917200

# %%
# To see the last 5 rows use tail() function
pd.DataFrame(data).tail()
# Out:
#             Date        Open        High         Low       Close   Adj_Close  \
# 1769  2022-08-18  173.750000  174.899994  173.119995  174.149994  174.149994
# 1770  2022-08-19  173.029999  173.740005  171.309998  171.520004  171.520004
# 1771  2022-08-22  169.690002  169.860001  167.139999  167.570007  167.570007
# 1772  2022-08-23  167.080002  168.710007  166.649994  167.229996  167.229996
# 1773  2022-08-24  167.320007  168.110001  166.250000  167.529999  167.529999
#
#         Volume
# 1769  62290100
# 1770  70211500
# 1771  69026800
# 1772  54147100
# 1773  53766800

# %%
# Lets try the info() function  ==>> I can see information about data in each column
pd.DataFrame(data).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1774 entries, 0 to 1773
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1774 non-null   object
#  1   Open       1774 non-null   object
#  2   High       1774 non-null   object
#  3   Low        1772 non-null   float64
#  4   Close      1774 non-null   object
#  5   Adj_Close  1774 non-null   object
#  6   Volume     1774 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 97.1+ KB

# %%
# Lets check our dataset for missing values by using isnull() function
pd.DataFrame(data).isnull() # Wow there is no null values
# Out:
#        Date   Open   High    Low  Close  Adj_Close  Volume
# 0     False  False  False   True  False      False   False
# 1     False  False  False  False  False      False   False
# 2     False  False  False  False  False      False   False
# 3     False  False  False  False  False      False   False
# 4     False  False  False  False  False      False   False
# ...     ...    ...    ...    ...    ...        ...     ...
# 1769  False  False  False  False  False      False   False
# 1770  False  False  False  False  False      False   False
# 1771  False  False  False  False  False      False   False
# 1772  False  False  False  False  False      False   False
# 1773  False  False  False  False  False      False   False
#
# [1774 rows x 7 columns]

# %%
pdDf = pd.read_csv('C:\\Users\\sulej\\OneDrive\\Рабочий стол\\7 semester\\Data Mining\\Apple_price_to_clean.csv')
pdDf.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2015-08-25  27.777500          -        NaN  25.934999      ERROR
# 1  2015-08-26  26.772499  27.472500  26.262501  27.422501  25.039267
# 2  2015-08-27  28.057501  28.309999  27.504999  28.230000  25.776581
# 3  2015-08-28  28.042500  28.327499  27.885000  28.322500  25.861042
# 4  2015-08-31  28.007500  28.632500  28.000000  28.190001  25.740063
#
#       Volume
# 0  414406400
# 1  387098400
# 2  338464400
# 3      ERROR
# 4  224917200

# %%
pdDf.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 1769  2022-08-18  173.750000  174.899994  173.119995  174.149994  174.149994
# 1770  2022-08-19  173.029999  173.740005  171.309998  171.520004  171.520004
# 1771  2022-08-22  169.690002  169.860001  167.139999  167.570007  167.570007
# 1772  2022-08-23  167.080002  168.710007  166.649994  167.229996  167.229996
# 1773  2022-08-24  167.320007  168.110001  166.250000  167.529999  167.529999
#
#         Volume
# 1769  62290100
# 1770  70211500
# 1771  69026800
# 1772  54147100
# 1773  53766800

# %%
pdDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1774 entries, 0 to 1773
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1773 non-null   object
#  1   Open       1774 non-null   object
#  2   High       1773 non-null   object
#  3   Low        1772 non-null   float64
#  4   Close      1772 non-null   object
#  5   Adj Close  1774 non-null   object
#  6   Volume     1773 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 97.1+ KB

# %%
pdDf.isnull()
# Out:
#        Date   Open   High    Low  Close  Adj Close  Volume
# 0     False  False  False   True  False      False   False
# 1     False  False  False  False  False      False   False
# 2     False  False  False  False  False      False   False
# 3     False  False  False  False  False      False   False
# 4     False  False  False  False  False      False   False
# ...     ...    ...    ...    ...    ...        ...     ...
# 1769  False  False  False  False  False      False   False
# 1770  False  False  False  False  False      False   False
# 1771  False  False  False  False  False      False   False
# 1772  False  False  False  False  False      False   False
# 1773  False  False  False  False  False      False   False
#
# [1774 rows x 7 columns]

# %%
pdDf.isnull().sum()
# Out:
# Date         1
# Open         0
# High         1
# Low          2
# Close        2
# Adj Close    0
# Volume       1
# dtype: int64

# %%
data_types
